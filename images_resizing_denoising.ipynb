# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os

# %%
directory = '/home/hossein/images/images_live'

# %%
room_types = os.listdir('/home/hossein/images/images_live')

# %%
import cv2 
imsiwe = 244
room = []
images = []
for i in room_types:
    single_image_path = str(directory + '/' + i)
    room.append(single_image_path)
    img = cv2.imread(single_image_path)
    img = cv2.resize(img, (imsize, imsize))
    images.append(img)
room
# Out:
# ['/home/hossein/images/images_live/1653478650.jpeg',
#  '/home/hossein/images/images_live/1653476190.jpeg',
#  '/home/hossein/images/images_live/1653478890.jpeg',
#  '/home/hossein/images/images_live/1653475980.jpeg',
#  '/home/hossein/images/images_live/1653477960.jpeg',
#  '/home/hossein/images/images_live/1653478200.jpeg',
#  '/home/hossein/images/images_live/1653477660.jpeg',
#  '/home/hossein/images/images_live/1653477060.jpeg',
#  '/home/hossein/images/images_live/1653479070.jpeg',
#  '/home/hossein/images/images_live/1653477450.jpeg',
#  '/home/hossein/images/images_live/1653478320.jpeg',
#  '/home/hossein/images/images_live/1653477300.jpeg',
#  '/home/hossein/images/images_live/1653479040.jpeg',
#  '/home/hossein/images/images_live/1653479430.jpeg',
#  '/home/hossein/images/images_live/1653476790.jpeg',
#  '/home/hossein/images/images_live/1653478860.jpeg',
#  '/home/hossein/images/images_live/1653477120.jpeg',
#  '/home/hossein/images/images_live/1653477930.jpeg',
# ...

# %%
plt.imshow(images[1])
plt.show()

# %%
# images = np.array(images)
# images.shape
# Out:
# (114, 244, 244, 3)

# %%
images = images.astype('float32')/255.0

# %%
images[1].shape
# Out:
# (244, 244, 3)

# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt

img = cv2.imread('/home/hossein/images/images_live/1653477990.jpeg')
#converted_img = cv2.cvtColor(img, cv2.COLOR_GRAY2BGR)

dst = cv2.fastNlMeansDenoisingColored(img,None,10,10,7,21)
xx = cv2.imwrite('/home/hossein/images/images_live/smooth.jpeg',dst)

plt.subplot(121),plt.imshow(img)
plt.subplot(122),plt.imshow(dst)
plt.show()
